# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import copy

# %%
import numpy as np
import scipy.stats

def mean_confidence_interval(data, confidence=0.95):
    a = 1.0 * np.array(data)
    n = len(a)
    m, se = np.mean(a), scipy.stats.sem(a)
    h = se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)
    return m, h

# %%
obj_l = ['obj_'+str(x) for x in range(5)]
obj_l
# Out:
# ['obj_0', 'obj_1', 'obj_2', 'obj_3', 'obj_4']

# %% [markdown]
# # Action Histogram

# %%
df = pd.read_csv('ToleranceConditioned/eval_results/obj_0_pos_tol_100_angle_tol1000_caps_8_15_action_x_dist.csv')

# %%
df['dis_force_length'] = (df['force_length']*10).apply(lambda x: int(x))
df['dis_obj_goal_dist'] = df['obj_goal_dist'].apply(lambda x: int(x))

# %%
sns.histplot(df[df['obj_goal_dist'] < 2], x='force_length', stat='probability', bins=20)
# Out:
# <Axes: xlabel='force_length', ylabel='Probability'>

# %%
sns.histplot(df[df['obj_goal_dist'] > 2], x='force_length', stat='probability', bins=20)
# Out:
# <Axes: xlabel='force_length', ylabel='Probability'>

# %%
plt.hist2d(
    df['dis_obj_goal_dist'], df['dis_force_length'], 
    bins=(df['dis_obj_goal_dist'].max(), df['dis_force_length'].max()), cmap=plt.cm.BuPu)
plt.show()

# %%
df
# Out:
#        obj_goal_dist  force_length  dis_force_length  dis_obj_goal_dist
# 0          53.666328      0.835098                 8                 53
# 1          53.666328      0.865880                 8                 53
# 2          53.061661      0.618336                 6                 53
# 3          51.148270      0.500188                 5                 51
# 4          49.051174      0.494341                 4                 49
# ...              ...           ...               ...                ...
# 11917       2.142873      0.686751                 6                  2
# 11918       1.221189      0.699572                 6                  1
# 11919       1.203804      0.709372                 7                  1
# 11920       1.447259      0.767899                 7                  1
# 11921       1.350715      0.638932                 6                  1
#
# [11922 rows x 4 columns]

# %% [markdown]
# # Testing pos_tol = 1.0

# %%
dir_path = 'ToleranceConditioned/eval_results/'

df_l = []
for o in obj_l:
    aux_df = pd.read_csv(dir_path + o + '.csv')
    aux_df['object'] = o
    df_l.append(aux_df)
df = pd.concat(df_l)

# %%
grouped_df = df.groupby(['object','capsule_width']).apply(lambda x: x.mean())
df_l = []
for o in obj_l:
    aux_df = grouped_df.loc[o].reset_index()
    aux_df['object'] = o
    df_l.append(aux_df)
df = pd.concat(df_l).reset_index(drop=True)

# %%
agg_df = pd.DataFrame()
agg_df['tuple'] = df.groupby('capsule_width').apply(lambda x: mean_confidence_interval(x['success']))

agg_df['mean'] = agg_df['tuple'].apply(lambda x: 100*x[0])
agg_df['confidence'] = agg_df['tuple'].apply(lambda x: 100*x[1])
agg_df[['mean', 'confidence']]
# Out:
#                 mean  confidence
# capsule_width
# 8.0            68.90   15.877043
# 9.0            90.44    6.803480
# 10.0           95.68    3.290292
# 11.0           97.36    1.606024
# 12.0           97.84    1.140034
# 13.0           98.76    0.952122
# 14.0           99.04    0.976109
# 15.0           98.86    1.026158

# %%
aux_df = df
aux_df['Object'] = aux_df['object']
aux_df['Success Rate (%)'] = 100*aux_df['success']
aux_df['Capsule Width'] = aux_df['capsule_width']
sns.set_style("darkgrid")
sns.lineplot(aux_df, x='Capsule Width', y='Success Rate (%)', hue='Object', style='Object')
# Out:
# <Axes: xlabel='Capsule Width', ylabel='Success Rate (%)'>

# %%
df
# Out:
#     capsule_width  success  time_steps  acc_reward object
# 0             8.0    0.534      22.954    3.715679  obj_0
# 1             9.0    0.854      24.658   11.419173  obj_0
# 2            10.0    0.953      25.972   13.572448  obj_0
# 3            11.0    0.960      27.721   13.895506  obj_0
# 4            12.0    0.967      28.123   13.942424  obj_0
# 5            13.0    0.977      28.467   14.010607  obj_0
# 6            14.0    0.977      27.421   14.248368  obj_0
# 7            15.0    0.975      29.328   14.016209  obj_0
# 8             8.0    0.808      22.462   10.572290  obj_1
# 9             9.0    0.962      21.581   14.418193  obj_1
# 10           10.0    0.979      20.327   15.012624  obj_1
# 11           11.0    0.984      21.494   15.067924  obj_1
# 12           12.0    0.986      21.015   14.844858  obj_1
# 13           13.0    0.996      19.534   15.443924  obj_1
# 14           14.0    0.997      20.122   15.450486  obj_1
# 15           15.0    0.992      20.674   15.139542  obj_1
# 16            8.0    0.569      21.521    4.586513  obj_2
# 17            9.0    0.839      25.281   11.059909  obj_2
# 18           10.0    0.913      24.314   12.837765  obj_2
# 19           11.0    0.959      24.211   14.017379  obj_2
# 20           12.0    0.970      22.900   14.536095  obj_2
# 21           13.0    0.983      23.428   14.737623  obj_2
# 22           14.0    0.995      23.756   14.993148  obj_2
# 23           15.0    0.987      24.773   14.784964  obj_2
# 24            8.0    0.749      27.294    8.567802  obj_3
# 25            9.0    0.924      28.119   12.784656  obj_3
# 26           10.0    0.964      25.377   14.203985  obj_3
# 27           11.0    0.984      24.379   14.629608  obj_3
# 28           12.0    0.986      24.373   14.744830  obj_3
# 29           13.0    0.989      23.325   14.837268  obj_3
# 30           14.0    0.991      23.055   14.763671  obj_3
# 31           15.0    0.996      24.307   15.050632  obj_3
# 32            8.0    0.785      23.419    9.757184  obj_4
# 33            9.0    0.943      23.270   13.919876  obj_4
# 34           10.0    0.975      23.559   14.653478  obj_4
# 35           11.0    0.981      21.366   14.863477  obj_4
# 36           12.0    0.983      20.931   14.888692  obj_4
# 37           13.0    0.993      21.356   15.258635  obj_4
# 38           14.0    0.992      21.492   15.054111  obj_4
# 39           15.0    0.993      20.467   15.234185  obj_4

# %%
df
# Out:
#    capsule_width  success  time_steps  acc_reward object
# 0            8.0    0.744      27.238    8.397524  obj_3
# 1            9.0    0.922      29.968   12.797233  obj_3
# 2           10.0    0.962      23.728   13.926400  obj_3
# 3           11.0    0.996      24.118   14.802896  obj_3
# 4           12.0    0.990      23.722   14.803175  obj_3
# 5           13.0    0.990      24.408   14.823324  obj_3
# 6           14.0    0.996      23.858   14.919284  obj_3
# 7           15.0    0.992      24.534   14.708337  obj_3

# %%
df
# Out:
#    capsule_width  success  time_steps  acc_re
obj_0_pos_tol_100_angle_tol1000_caps_8_15
# 7  obj_0_pos_tol_100_angle_tol1000_caps_8_15

# %%
df
# Out:
#    capsule_width  success  time_steps  acc_reward  \
# 0            8.0    0.478      24.256    2.241933
# 1            9.0    0.814      28.806   10.124572
# 2           10.0    0.918      29.246   12.606855
# 3           11.0    0.940      31.122   13.016124
# 4           12.0    0.962      27.866   13.751627
# 5           13.0    0.984      26.972   14.449367
# 6           14.0    0.984      27.832   14.591949
# 7           15.0    0.992      27.048   14.591387
#
#                                       object
# 0  obj_0_pos_tol_100_angle_tol1000_caps_8_15
# 1  obj_0_pos_tol_100_angle_tol1000_caps_8_15
# 2  obj_0_pos_tol_100_angle_tol1000_caps_8_15
# 3  obj_0_pos_tol_100_angle_tol1000_caps_8_15
# 4  obj_0_pos_tol_100_angle_tol1000_caps_8_15
# 5  obj_0_pos_tol_100_angle_tol1000_caps_8_15
# 6  obj_0_pos_tol_100_angle_tol1000_caps_8_15
# 7  obj_0_pos_tol_100_angle_tol1000_caps_8_15

# %%
aux_df = df
aux_df['Object'] = aux_df['object']
aux_df['Success Rate (%)'] = 100*aux_df['success']
aux_df['Capsule Width'] = aux_df['capsule_width']
sns.set_style("darkgrid")
sns.lineplot(aux_df, x='Capsule Width', y='Success Rate (%)', hue='Object', style='Object')
# Out:
# <Axes: xlabel='Capsule Width', ylabel='Success Rate (%)'>

# %% [markdown]
# # Capsule Width X Success

# %%
dir_path = 'ToleranceConditioned/eval_results/'

# %%
df_l = []
for o in obj_l:
    aux_df = pd.read_csv(dir_path + o + '.csv')
    aux_df['object'] = o
    df_l.append(aux_df)
df = pd.concat(df_l)

# %%
grouped_df = df.groupby(['object','capsule_width']).apply(lambda x: x.mean())

# %%
df_l = []
for o in obj_l:
    aux_df = grouped_df.loc[o].reset_index()
    aux_df['object'] = o
    df_l.append(aux_df)
df = pd.concat(df_l).reset_index(drop=True)

# %%
# 0.5
aux_df = df
aux_df['Object'] = aux_df['object']
aux_df['Success Rate (%)'] = 100*aux_df['success']
aux_df['Capsule Width'] = aux_df['capsule_width']
sns.set_style("darkgrid")
sns.lineplot(aux_df, x='Capsule Width', y='Success Rate (%)', hue='Object', style='Object')
# Out:
# <Axes: xlabel='Capsule Width', ylabel='Success Rate (%)'>

# %%
# 0.75
aux_df = df
aux_df['Object'] = aux_df['object']
aux_df['Success Rate (%)'] = 100*aux_df['success']
aux_df['Capsule Width'] = aux_df['capsule_width']
sns.set_style("darkgrid")
sns.lineplot(aux_df, x='Capsule Width', y='Success Rate (%)', hue='Object', style='Object')
# Out:
# <Axes: xlabel='Capsule Width', ylabel='Success Rate (%)'>

# %%
# 1.0
aux_df = df
aux_df['Object'] = aux_df['object']
aux_df['Success Rate (%)'] = 100*aux_df['success']
aux_df['Capsule Width'] = aux_df['capsule_width']
sns.set_style("darkgrid")
sns.lineplot(aux_df, x='Capsule Width', y='Success Rate (%)', hue='Object', style='Object')
# Out:
# <Axes: xlabel='Capsule Width', ylabel='Success Rate (%)'>

# %%
# 2.0
aux_df = df
aux_df['Object'] = aux_df['object']
aux_df['Success Rate (%)'] = 100*aux_df['success']
aux_df['Capsule Width'] = aux_df['capsule_width']
sns.set_style("darkgrid")
sns.lineplot(aux_df, x='Capsule Width', y='Success Rate (%)', hue='Object', style='Object')
# Out:
# <Axes: xlabel='Capsule Width', ylabel='Success Rate (%)'>
